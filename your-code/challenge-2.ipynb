# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
# Your Code Here

# %% [markdown]
# ## Challenge
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic = pd.read_csv("../data/titanic.csv")
titanic.sample(5)
# Out:
#       PassengerId  Survived  Pclass                           Name  Gender  \
# 797           798       1.0       3               Osman, Mrs. Mara  female
# 19             20       1.0       3        Masselmani, Mrs. Fatima  female
# 1212         1213       NaN       3          Krekorian, Mr. Neshan    male
# 922           923       NaN       2  Jefferys, Mr. Clifford Thomas    male
# 554           555       1.0       3             Ohman, Miss. Velin  female
#
#             Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 797   31.000000      0      0      349244   8.6833     U0        S
# 19    27.749836      0      0        2649   7.2250     U0        C
# 1212  25.000000      0      0        2654   7.2292  F E57        C
# 922   24.000000      2      0  C.A. 31029  31.5000     U0        S
# 554   22.000000      0      0      347085   7.7750     U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
print(titanic.select_dtypes(["float","int"]))

print("Categorical:")
print("Survived,Pclass,Gender,Cabin,Embarked")
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]
# Categorical:
# Survived,Pclass,Gender,Cabin,Embarked

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
sns.set(rc={"figure.figsize": (12, 6)})
plt.style.use="classic"

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
sns.histplot(x=titanic.Age)
plt.show()

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
'''Depending on bin size, it will contains more or less elements... if bin is greater, more elements'''

sns.histplot(x=titanic.Age,bins=5)
plt.show()
sns.histplot(x=titanic.Age,bins=15)
plt.show()

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
titanic.groupby(["Gender"])["Gender"].count().plot(kind="bar");

# %%
sns.countplot(x=titanic.Gender);
plt.xlabel("Passengers")
plt.show()

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
sns.countplot(x=titanic.Pclass);
plt.xlabel("Class")
plt.ylabel("Passengers")

plt.show()

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it and list all the info it's giving you.

# %% [markdown]
# [Hint](https://seaborn.pydata.org/generated/seaborn.boxplot.html)

# %%
sns.boxplot( x=titanic["Age"] );
plt.show()

# %%
"""
50% of passengers are around 20-40 years but median value is close to 30. Distribution is quite symmetrical.
Minimum is 0 and maximum is 60. Values out of this range we assume them as outliers. These values are out of "whiskers" ( greater than 60 years)

"""
# Out:
# '\n50% of passengers are around 20-40 years but median value is close to 30. \nMinimum is 0 and maximum is 60. Values out of this values could be outliers. These values are out of "whiskers" ( greater than 60 years)\n\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
plt.scatter(titanic["Age"],titanic["Fare"])
plt.xlabel("Age")
plt.ylabel("Fare")
plt.show()

# %%
sns.scatterplot(x=titanic["Age"], y=titanic["Fare"]);
plt.xlabel("Age")
plt.ylabel("Fare")
plt.show()

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
graph_10= sns.heatmap(titanic.select_dtypes(["float","int"]).corr(),square=True,annot=True);
plt.show(graph_10)

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
Fare is correlated with Class 
Survived with Class
Age with Class

"""
# Out:
# '\nFare is correlated with Class \nSurvived with Class\nAge with Class\n\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
graph_4 = sns.histplot(x=titanic["Age"], hue=titanic["Pclass"]);
plt.ylabel("Passengers")
plt.legend( ['1st Class', '2nd Class', '3rd Class']);
plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
graph = sns.FacetGrid(titanic, col ='Gender') 
# map the above form facetgrid with some attributes 
graph.map(sns.histplot, "Age") 
plt.show()
